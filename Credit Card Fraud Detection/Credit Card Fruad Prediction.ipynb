# %% [markdown]
# # Credit Card Fraud Prediction

# %%
#Importing requried library
import pandas as pd
import numpy as np

# %%
# importing required dataset
df = pd.read_csv(r"C:\Users\Aayush\Documents\Python Learning\pandas-project\Data Analysis with python\Credit Card Fraud Detection\creditcard.csv")
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
pd.options.display.max_columns = None

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
# shape of the dataset
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
df['Amount'] = sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
df = df.drop(['Time'],axis=1)

df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
# checking if dataset has any duplicate values

df.duplicated().any()
# Out:
# True

# %%
# remove duplicate values

df = df.drop_duplicates()

df.shape
# Out:
# (275663, 30)

# %%
df['Class'].value_counts()

# here 0 is considers as Normal Transaction and 1 as Fraud Transaction
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = sns.countplot(x='Class', data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
X = df.drop('Class',axis =1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"----------{name}-----------")
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(f"\n Accuaracy: {accuracy_score(y_test, y_pred)}")
    print(f"\n Precision: {precision_score(y_test, y_pred)}")
    print(f"\n Recall: {recall_score(y_test, y_pred)}")
    print(f"\n F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# ----------Logistic Regression-----------
#
#  Accuaracy: 0.9991293727856443
#
#  Precision: 0.8478260869565217
#
#  Recall: 0.5735294117647058
#
#  F1 Score: 0.6842105263157895
# ----------Decision Tree Classifier-----------
#
#  Accuaracy: 0.9991051886963567
#
#  Precision: 0.6962025316455697
#
#  Recall: 0.8088235294117647
#
#  F1 Score: 0.7482993197278912

# %%
log = LogisticRegression()

# %%
log.fit(X_train, y_train)
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.9991293727856443

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.8478260869565217

# %%
recall_score(y_test, y_pred1)
# Out:
# 0.5735294117647058

# %%
f1_score(y_test, y_pred1)
# Out:
# 0.6842105263157895

# %% [markdown]
# ### Undersampling

# %%
# Undersampling

normal = df[df['Class']==0]
fraud = df[df['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample = normal.sample(n=473)
normal_sample.shape
# Out:
# (473, 30)

# %%
new_df = pd.concat([normal_sample,fraud],ignore_index=True)

new_df.head(10)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.979867 -0.570424 -0.036981  0.136384 -0.827560  0.071181 -1.021754
# 1 -0.855283  1.425676  1.029014  1.302866 -0.203433  0.094344  0.386706
# 2  1.223520  0.038267  0.425487  0.643034 -0.331595 -0.201114 -0.140723
# 3  0.759267 -1.460843 -0.748784 -0.714871  1.067358  3.966829 -0.885266
# 4 -5.789291  2.802416 -1.393612 -0.649161 -3.023768 -0.363118 -1.526406
# 5 -1.140843  0.496185  2.265965 -2.018750 -0.771400 -0.601713  0.092459
# 6 -0.356720  1.013338  1.612979  1.062264  0.235296  0.074688  0.563299
# 7 -0.220733  0.758576 -0.152820 -0.538302  2.541137  3.427172  0.027463
# 8 -2.153977 -0.605186 -0.437067  1.578947 -2.434029  1.434163  1.458081
# 9  2.011143 -0.859515 -0.925876 -1.529391 -0.628482 -0.541867 -0.588058
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.213178  1.189166  0.161836  0.362573  0.772962 -0.006363 -0.119889
# ...

# %%
new_df.shape
# Out:
# (946, 30)

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
X = new_df.drop('Class',axis =1)
y = new_df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.3, random_state=42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifer": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"--------{name}----------")
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(f"\n Accuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\n Precision: {precision_score(y_test,y_pred)}")
    print(f"\n Recall: {recall_score(y_test,y_pred)}")
    print(f"\n F1 Score: {f1_score(y_test,y_pred)}")
# Out:
# --------Logistic Regression----------
#
#  Accuracy: 0.9507042253521126
#
#  Precision: 0.9779411764705882
#
#  Recall: 0.9236111111111112
#
#  F1 Score: 0.95
# --------Decision Tree Classifer----------
#
#  Accuracy: 0.9014084507042254
#
#  Precision: 0.9027777777777778
#
#  Recall: 0.9027777777777778
#
#  F1 Score: 0.9027777777777778

# %%
# OVersampling

X = df.drop('Class',axis =1)
y = df['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res, y_res = SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size= 0.3, random_state = 42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifer": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"--------{name}----------")
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(f"\n Accuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\n Precision: {precision_score(y_test,y_pred)}")
    print(f"\n Recall: {recall_score(y_test,y_pred)}")
    print(f"\n F1 Score: {f1_score(y_test,y_pred)}")
# Out:
# --------Logistic Regression----------
#
#  Accuracy: 0.9456315030827186
#
#  Precision: 0.9740936653335054
#
#  Recall: 0.915497568842381
#
#  F1 Score: 0.9438870865915328
# --------Decision Tree Classifer----------
#
#  Accuracy: 0.9979468730695156
#
#  Precision: 0.9969144018779798
#
#  Recall: 0.9989814601496284
#
#  F1 Score: 0.9979468606348381

# %%
dtc = DecisionTreeClassifier()

dtc.fit(X_res, y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
joblib.dump(dtc,"Credit_card_prediction_model.pkl")
# Out:
# ['Credit_card_prediction_model.pkl']

# %%
model = joblib.load("Credit_card_prediction_model.pkl")

# %%
pred = model.predict([[-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]])
# Out:
# C:\Users\Aayush\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pred[0]
# Out:
# 0

# %%
if pred[0] == 0:
    print("Normal Transaction")
else:
    print("Fraud Transaction")
# Out:
# Normal Transaction

# %%
pred2 = model.predict([[-1.35835406159823,-1.34016307473609,1.77320934263119,0.379779593034328,-0.503198133318193,1.80049938079263,0.791460956450422,0.247675786588991,-1.51465432260583,0.207642865216696,0.624501459424895,0.066083685268831,0.717292731410831,-0.165945922763554,2.34586494901581,-2.89008319444231,1.10996937869599,-0.121359313195888,-2.26185709530414,0.524979725224404,0.247998153469754,0.771679401917229,0.909412262347719,-0.689280956490685,-0.327641833735251,-0.139096571514147,-0.0553527940384261,-0.0597518405929204,378.66]])
# Out:
# C:\Users\Aayush\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pred2[0]
# Out:
# 0

# %%
pred3 = model.predict([[-2.3122265423263,1.95199201064158,-1.60985073229769,3.9979055875468,-0.522187864667764,-1.42654531920595,-2.53738730624579,1.39165724829804,-2.77008927719433,-2.77227214465915,3.20203320709635,-2.89990738849473,-0.595221881324605,-4.28925378244217,0.389724120274487,-1.14074717980657,-2.83005567450437,-0.0168224681808257,0.416955705037907,0.126910559061474,0.517232370861764,-0.0350493686052974,-0.465211076182388,0.320198198514526,0.0445191674731724,0.177839798284401,0.261145002567677,-0.143275874698919,0]])
# Out:
# C:\Users\Aayush\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pred3[0]
# Out:
# 1

# %% [markdown]
# Fraud Transaction
